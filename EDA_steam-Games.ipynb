# %% [markdown]
#                                                             INTRODUCTION
#
#
# * What is Exploratory Data Analysis ?
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.
#
#
# * How to perform Exploratory Data Analysis ?
#
# This is one such question that everyone is keen on knowing the answer. Well, the answer is it depends on the data set that you are working. There is no one method or common methods in order to perform EDA, whereas in this tutorial you can understand some common methods and plots that would be used in the EDA process.

# %% [markdown]
# 1. Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt             
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# 2. Loading the data into the data frame.

# %%
df = pd.read_csv("Steam_Games.csv")
# To display the top 5 rows 
df.head(5)
# Out:
#      user_id      name  behavior  hours  \
# 0  151603712  HuniePop  purchase    1.0
# 1  151603712  HuniePop      play    8.5
# 2   86338111  HuniePop  purchase    1.0
# 3   86338111  HuniePop      play   34.0
# 4   84455820  HuniePop  purchase    1.0
#
#                                                  url types  \
# 0  https://store.steampowered.com/app/339800/Huni...   app
# 1  https://store.steampowered.com/app/339800/Huni...   app
# 2  https://store.steampowered.com/app/339800/Huni...   app
# 3  https://store.steampowered.com/app/339800/Huni...   app
# 4  https://store.steampowered.com/app/339800/Huni...   app
#
#                                         desc_snippet  \
# 0  HuniePop is a unique sim experience for PC, Ma...
# 1  HuniePop is a unique sim experience for PC, Ma...
# 2  HuniePop is a unique sim experience for PC, Ma...
# 3  HuniePop is a unique sim experience for PC, Ma...
# 4  HuniePop is a unique sim experience for PC, Ma...
#
# ...

# %%
df.tail(5)                        # To display the botton 5 rows
# Out:
#          user_id        name  behavior  hours  \
# 24603   60859695        Fire      play    3.1
# 24604   60859695       Kuros  purchase    1.0
# 24605   60859695       Kuros      play    2.5
# 24606  154230723  ReignMaker  purchase    1.0
# 24607  154230723   Windforge  purchase    1.0
#
#                                                      url types  \
# 24603    https://store.steampowered.com/app/325520/Fire/   app
# 24604    https://store.steampowered.com/app/36240/Kuros/   app
# 24605    https://store.steampowered.com/app/36240/Kuros/   app
# 24606  https://store.steampowered.com/app/286200/Reig...   app
# 24607  https://store.steampowered.com/app/266170/Wind...   app
#
#                                             desc_snippet recent_reviews  \
# 24603  FIRE is an exploration-adventure with intuitiv...            NaN
# 24604  When Katya, a young explorer with no memory of...            NaN
# 24605  When Katya, a young explorer with no memory of...            NaN
# ...

# %% [markdown]
# 3. Checking the types of data

# %%
df.dtypes
# Out:
# user_id                       int64
# name                         object
# behavior                     object
# hours                       float64
# url                          object
# types                        object
# desc_snippet                 object
# recent_reviews               object
# all_reviews                  object
# release_date                 object
# developer                    object
# publisher                    object
# popular_tags                 object
# game_details                 object
# languages                    object
# achievements                float64
# genre                        object
# game_description             object
# mature_content               object
# minimum_requirements         object
# recommended_requirements     object
# original_price               object
# discount_price               object
# dtype: object

# %% [markdown]
# 4. Detecting Outliers
# - An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them.

# %%
sns.boxplot(x=df['hours'])
# Out:
# <Axes: xlabel='hours'>

# %%
sns.boxplot(x=df['achievements'])
# Out:
# <Axes: xlabel='achievements'>

# %% [markdown]
# 5. (Barplot):
# - Chart of number of games/applications by each type (genre).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ file CSV
data = pd.read_csv('Steam_Games.csv')

# Tạo biểu đồ cột cho phân phối số lượng trò chơi theo thể loại
genre_counts = data['genre'].value_counts().head(15)
plt.figure(figsize=(16, 10))
genre_counts.plot(kind='bar')
plt.title('Phân phối số lượng trò chơi theo thể loại')
plt.xlabel('Thể loại')
plt.ylabel('Số lượng')
plt.xticks(rotation=85)
plt.show()

# %% [markdown]
# - chart for the 10 games with the highest number of players

# %%
# Tạo biểu đồ cho 10 trò chơi có số người chơi cao nhất
top_10_games = df['name'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
top_10_games.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Top 10 Games by Number of Players')
plt.xlabel('game_name')
plt.ylabel('Number of Players')

# Hiển thị biểu đồ
plt.xticks(rotation=75)  # Xoay nhãn trục x để dễ đọc
plt.tight_layout()  # Đảm bảo nhãn được hiển thị đầy đủ
plt.show()

# %% [markdown]
# 6. Pie Chart: percentage of the most popular publishers.

# %%
publisher_counts = df['publisher'].value_counts().head(10)
plt.figure(figsize=(8, 8))
plt.pie(publisher_counts, labels=publisher_counts.index, autopct='%1.1f%%')
plt.title('Tỷ lệ phần trăm của các nhà xuất bản phổ biến nhất')
plt.show()

# %% [markdown]
# 7. Boxplot: Shows the distribution and outliers of the user's hours.

# %%
plt.figure(figsize=(8, 8))
plt.boxplot(df['hours'].dropna())
plt.title('Phân phối số giờ chơi')
plt.ylabel('Số giờ')
plt.show()

# %% [markdown]
# 8. Heatmap: Hiển thị ma trận tương quan giữa các biến số lượng .

# %%
# Tính ma trận tương quan giữa các biến số lượng
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = data[numeric_columns].corr()

# Vẽ heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Ma trận tương quan')
plt.show()

# %% [markdown]
#                                                     NHẬN XÉT DATASET

# %% [markdown]
# Khi thực hiện EDA (Exploratory Data Analysis) trên tập dữ liệu Steam_Games.csv, ta có thể rút ra một số kết luận sau:
#
# 1. **Phân phối thể loại trò chơi/ứng dụng:** Thể loại game có sự đa dạng, với một số thể loại nhất định chiếm tỷ lệ lớn hơn trong tập dữ liệu, ví dụ như game hành động, phiêu lưu, chiến lược.
#
# 2. **Nhà phát triển và nhà xuất bản phổ biến:** Có một số nhà phát triển và nhà xuất bản nổi bật được đánh giá cao như Valve, Smartly Dressed Games...
#
# 3. **Phân phối số giờ chơi:** Phần lớn người dùng dành một lượng thời gian tương đối nhất định cho trò chơi/ứng dụng, tuy nhiên có một số ít điểm ngoại lệ với số giờ chơi rất cao tới gần 5000 giờ.
#
# 4. **Tương quan giữa các biến số lượng:** Có thể xác định được mối tương quan giữa các thuộc tính số lượng như giá gốc, giá giảm, số lượng thành tựu, số giờ chơi.
#
# 6. **Thông tin từ các biến văn bản:** Có thể trích xuất thông tin hữu ích từ các trường văn bản như mô tả trò chơi(desc_snippet), đánh giá(all_reviews), từ khóa phổ biến để hiểu thêm về tính chất và nội dung của Games.
#
# 7. **Các xu hướng hoặc thông tin đặc biệt:** Có thể phát hiện các xu hướng, thông tin đặc biệt hoặc điểm nổi bật từ dữ liệu sau khi thực hiện phân tích và trực quan hóa.
